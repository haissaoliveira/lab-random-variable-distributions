# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import uniform
from scipy.stats import norm
from scipy.stats import expon

# %%
mk_customer = pd.read_csv(r'C:\Users\haiss\Desktop\Ironhack\lab-random-variable-distributions\files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv')
mk_customer
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
#  ## Get the numerical variables from our dataset.

# %%
numeric_customer = mk_customer.select_dtypes(include=[np.number])
numeric_customer
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# ## Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.

# %%
plt.hist(numeric_customer['Customer Lifetime Value']) 

plt.xlabel(' ')
plt.ylabel('Frequency')
plt.title('Customer Lifetime Value')
plt.show()

# %%
plt.hist(numeric_customer['Total Claim Amount']) 

plt.xlabel(' ')
plt.ylabel('Frequency')
plt.title('Total Claim Amount')
plt.show()

# %%
plt.hist(numeric_customer['Monthly Premium Auto']) 

plt.xlabel(' ')
plt.ylabel('Frequency')
plt.title('Monthly Premium Auto')
plt.show()

# %% [markdown]
# ## Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
## Standard deviation

std_dev = np.std(numeric_customer)
std_dev
# Out:
# Customer Lifetime Value           6870.591478
# Income                           30378.241676
# Monthly Premium Auto                34.406084
# Months Since Last Claim             10.072705
# Months Since Policy Inception       27.904463
# Number of Open Complaints            0.910334
# Number of Policies                   2.390051
# Total Claim Amount                 290.484189
# dtype: float64

# %%
plt.hist(std_dev['Customer Lifetime Value']) 

plt.xlabel(' ')
plt.ylabel('Frequency')
plt.title('Customer Lifetime Value')
plt.show()

# %%
plt.hist(std_dev['Total Claim Amount']) 

plt.xlabel(' ')
plt.ylabel('Frequency')
plt.title('Total Claim Amount')
plt.show()

# %%
plt.hist(std_dev['Monthly Premium Auto']) 

plt.xlabel(' ')
plt.ylabel('Frequency')
plt.title('Monthly Premium Auto')
plt.show()
